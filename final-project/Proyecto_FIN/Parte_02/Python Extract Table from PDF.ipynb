# %% [markdown]
# # Python Extract Table from PDF

# %% [markdown]
# Example PDFs
#
# * McKinsey Global Institute Disruptive technologies
#
# https://www.mckinsey.com/~/media/McKinsey/Business%20Functions/McKinsey%20Digital/Our%20Insights/Disruptive%20technologies/MGI_Disruptive_technologies_Full_report_May2013.ashx
#
# * Food Calories List
#
# http://www.uncledavesenterprise.com/file/health/Food%20Calories%20List.pdf

# %% [markdown]
# ## With tabula-py
#
# #### Installation
#
# https://pypi.org/project/tabula-py/
#
# `pip install tabula-py`
#
# #### tabula-py docs
#
# https://www.pydoc.io/pypi/tabula-py-0.9.0/autoapi/wrapper/index.html

# %%
#pip install tabula-py
# Out:
# Requirement already satisfied: tabula-py in d:\programdata\anaconda3\lib\site-packages (2.0.4)
# Requirement already satisfied: pandas in d:\programdata\anaconda3\lib\site-packages (from tabula-py) (0.25.1)
# Requirement already satisfied: distro in d:\programdata\anaconda3\lib\site-packages (from tabula-py) (1.4.0)
# Requirement already satisfied: numpy in d:\programdata\anaconda3\lib\site-packages (from tabula-py) (1.16.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in d:\programdata\anaconda3\lib\site-packages (from pandas->tabula-py) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in d:\programdata\anaconda3\lib\site-packages (from pandas->tabula-py) (2019.3)
# Requirement already satisfied: six>=1.5 in d:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->tabula-py) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install tabulate
# Out:
# Collecting tabulate
#   Downloading https://files.pythonhosted.org/packages/c4/41/523f6a05e6dc3329a5660f6a81254c6cd87e5cfb5b7482bae3391d86ec3a/tabulate-0.8.6.tar.gz (45kB)
# Building wheels for collected packages: tabulate
#   Building wheel for tabulate (setup.py): started
#   Building wheel for tabulate (setup.py): finished with status 'done'
#   Created wheel for tabulate: filename=tabulate-0.8.6-cp37-none-any.whl size=23279 sha256=56b2ed435082571298573768684315ea275bff3964b4ef7ab36a86683e1da9c5
#   Stored in directory: C:\Users\aquir\AppData\Local\pip\Cache\wheels\9c\9b\f4\eb243fdb89676ec00588e8c54bb54360724c06e7fafe95278e
# Successfully built tabulate
# Installing collected packages: tabulate
# Successfully installed tabulate-0.8.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from tabula import read_pdf
from tabulate import tabulate

# %%
df = read_pdf("Food Calories List.pdf")
df
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# Got stderr: feb 26, 2020 3:34:51 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# ADVERTENCIA: New fonts found, font cache will be re-built
# feb 26, 2020 3:34:51 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# ADVERTENCIA: Building on-disk font cache, this may take a while
# feb 26, 2020 3:34:53 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# ADVERTENCIA: Finished building on-disk font cache, found 373 fonts
# [              BREADS & CEREALS               Portion size *  \
#  0          Bagel ( 1 average )               140 cals (45g)
#  1           Biscuit digestives        86 cals (per biscuit)
#  2                   Jaffa cake        48 cals (per biscuit)
#  3    Bread white (thick slice)       96  cals (1 slice 40g)
#  4      Bread wholemeal (thick)       88  cals (1 slice 40g)
#  5                     Chapatis                     250 cals
#  6                   Cornflakes              130  cals (35g)
#  7                 Crackerbread            17 cals per slice
#  8               Cream crackers        35 cals (per cracker)
#  9                     Crumpets        93 cals (per crumpet)
#  10   Flapjacks basic fruit mix                     320 cals
#  11           Macaroni (boiled)              238 cals (250g)
#  12                      Muesli              195  cals (50g)
#  13         Naan bread (normal)  300 cals (small plate size)
#  14            Noodles (boiled)              175 cals (250g)
#  15     Pasta ( normal boiled )              330 cals (300g)
#  16   Pasta (wholemeal boiled )              315 cals (300g)
#  17  Porridge oats (with water)              193 cals (350g)
#  18         Potatoes** (boiled)              210 cals (300g)
#  19          Potatoes** (roast)              420 cals (300g)
#
#     per 100 grams (3.5 oz)  Unnamed: 0 energy content
#  0                310 cals         NaN         Medium
#  1                480 cals         NaN           High
#  2                370 cals         NaN       Med-High
#  3                240 cals         NaN         Medium
#  4                220 cals         NaN        Low-med
#  5                300 cals         NaN         Medium
#  6                370 cals         NaN       Med-High
#  7                325 cals         NaN    Low Calorie
#  8                440 cals         NaN  Low / portion
#  9                198 cals         NaN        Low-Med
#  10               500 cals         NaN           High
#  11                95 cals         NaN    Low calorie
#  12               390 cals         NaN       Med-high
#  13               320 cals         NaN         Medium
#  14                70 cals         NaN    Low calorie
#  15               110 cals         NaN    Low calorie
#  16               105 cals         NaN    Low calorie
#  17                55 cals         NaN    Low calorie
#  18                70 cals         NaN    Low calorie
#  19               140 cals         NaN         Medium  ]

# %%
df = read_pdf("Food Calories List.pdf")
df = df.dropna(axis='columns')
df
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-53588eced423> in <module>
#       1 df = read_pdf("Food Calories List.pdf")
# ----> 2 df = df.dropna(axis='columns')
#       3 df
#
# AttributeError: 'list' object has no attribute 'dropna'

# %%
df = read_pdf("Food Calories List.pdf", pages=3)
print (tabulate(df))
# Out:
# ---------  ----------------  --------  ------
# Fish cake  90 cals per cake  200 cals  Medium
# ---------  ----------------  --------  ------

# %%
df = read_pdf("Food Calories List.pdf", pages=3, output_format="json")
df
# Out:
# [{'extraction_method': 'lattice',
#   'top': 59.238052,
#   'left': 66.551025,
#   'width': 478.8936767578125,
#   'height': 673.64453125,
#   'right': 545.4447,
#   'bottom': 732.88257,
#   'data': [[{'top': 59.238052,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.648460388183594,
#      'text': 'Fish cake'},
#     {'top': 59.238052,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.648460388183594,
#      'text': '90 cals per cake'},
#     {'top': 59.238052,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.648460388183594,
#      'text': '200 cals'},
#     {'top': 59.238052,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.648460388183594,
#      'text': 'Medium'}],
#    [{'top': 81.88651,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.440391540527344,
#      'text': 'Fish fingers'},
#     {'top': 81.88651,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.440391540527344,
#      'text': '50 cals per piece'},
#     {'top': 81.88651,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.440391540527344,
#      'text': '220 cals'},
#     {'top': 81.88651,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.440391540527344,
#      'text': 'Medium'}],
#    [{'top': 104.326904,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.559585571289062,
#      'text': 'Gammon'},
#     {'top': 104.326904,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.559585571289062,
#      'text': '320 cals'},
#     {'top': 104.326904,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.559585571289062,
#      'text': '280 cals'},
#     {'top': 104.326904,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.559585571289062,
#      'text': 'Med-High'}],
#    [{'top': 126.88649,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.440338134765625,
#      'text': 'Haddock fresh'},
#     {'top': 126.88649,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.440338134765625,
#      'text': '200 cals'},
#     {'top': 126.88649,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.440338134765625,
#      'text': '110 cals'},
#     {'top': 126.88649,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.440338134765625,
#      'text': 'Low calorie'}],
#    [{'top': 149.32683,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 20.146591186523438,
#      'text': 'Halibut fresh'},
#     {'top': 149.32683,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 20.146591186523438,
#      'text': '220 cals'},
#     {'top': 149.32683,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 20.146591186523438,
#      'text': '125 cals'},
#     {'top': 149.32683,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 20.146591186523438,
#      'text': 'Low calorie'}],
#    [{'top': 169.47342,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 4.1438446044921875,
#      'text': ''},
#     {'top': 169.47342,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 4.1438446044921875,
#      'text': ''},
#     {'top': 169.47342,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 4.1438446044921875,
#      'text': ''},
#     {'top': 169.47342,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 4.1438446044921875,
#      'text': ''}],
#    [{'top': 173.61726,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 20.709671020507812,
#      'text': 'Ham'},
#     {'top': 173.61726,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 20.709671020507812,
#      'text': '6 cals'},
#     {'top': 173.61726,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 20.709671020507812,
#      'text': '240 cals'},
#     {'top': 173.61726,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 20.709671020507812,
#      'text': 'Medium'}],
#    [{'top': 194.32693,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.559646606445312,
#      'text': 'Herring fresh grilled'},
#     {'top': 194.32693,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.559646606445312,
#      'text': '300 cals'},
#     {'top': 194.32693,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.559646606445312,
#      'text': '200 cals'},
#     {'top': 194.32693,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.559646606445312,
#      'text': 'Medium'}],
#    [{'top': 216.88658,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.44049072265625,
#      'text': 'Kidney'},
#     {'top': 216.88658,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.44049072265625,
#      'text': '200 cals'},
#     {'top': 216.88658,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.44049072265625,
#      'text': '160 cals'},
#     {'top': 216.88658,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.44049072265625,
#      'text': 'Medium'}],
#    [{'top': 239.32707,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 20.146194458007812,
#      'text': 'Kipper'},
#     {'top': 239.32707,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 20.146194458007812,
#      'text': '200 cals'},
#     {'top': 239.32707,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 20.146194458007812,
#      'text': '120 cals'},
#     {'top': 239.32707,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 20.146194458007812,
#      'text': 'Low calorie'}],
#    [{'top': 259.47327,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 4.143890380859375,
#      'text': ''},
#     {'top': 259.47327,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 4.143890380859375,
#      'text': ''},
#     {'top': 259.47327,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 4.143890380859375,
#      'text': ''},
#     {'top': 259.47327,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 4.143890380859375,
#      'text': ''}],
#    [{'top': 263.61716,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 20.710052490234375,
#      'text': 'Liver'},
#     {'top': 263.61716,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 20.710052490234375,
#      'text': '200 cals'},
#     {'top': 263.61716,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 20.710052490234375,
#      'text': '150 cals'},
#     {'top': 263.61716,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 20.710052490234375,
#      'text': 'Medium'}],
#    [{'top': 284.3272,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.5594482421875,
#      'text': 'Liver pate'},
#     {'top': 284.3272,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.5594482421875,
#      'text': '150 cals'},
#     {'top': 284.3272,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.5594482421875,
#      'text': '300 cals'},
#     {'top': 284.3272,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.5594482421875,
#      'text': 'Medium'}],
#    [{'top': 306.88666,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.4405517578125,
#      'text': 'Lamb (roast)'},
#     {'top': 306.88666,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.4405517578125,
#      'text': '300 cals'},
#     {'top': 306.88666,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.4405517578125,
#      'text': '300 cals'},
#     {'top': 306.88666,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.4405517578125,
#      'text': 'Med-High'}],
#    [{'top': 329.3272,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 20.14617919921875,
#      'text': 'Lobster boiled'},
#     {'top': 329.3272,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 20.14617919921875,
#      'text': '200 cals'},
#     {'top': 329.3272,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 20.14617919921875,
#      'text': '100 cals'},
#     {'top': 329.3272,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 20.14617919921875,
#      'text': 'Low calorie'}],
#    [{'top': 349.4734,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 4.143768310546875,
#      'text': ''},
#     {'top': 349.4734,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 4.143768310546875,
#      'text': ''},
#     {'top': 349.4734,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 4.143768310546875,
#      'text': ''},
#     {'top': 349.4734,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 4.143768310546875,
#      'text': ''}],
#    [{'top': 353.61716,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 20.7100830078125,
#      'text': 'Luncheon meat'},
#     {'top': 353.61716,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 20.7100830078125,
#      'text': '300 cals'},
#     {'top': 353.61716,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 20.7100830078125,
#      'text': '400 cals'},
#     {'top': 353.61716,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 20.7100830078125,
#      'text': 'High'}],
#    [{'top': 374.32724,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.559417724609375,
#      'text': 'Mackeral'},
#     {'top': 374.32724,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.559417724609375,
#      'text': '320 cals'},
#     {'top': 374.32724,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.559417724609375,
#      'text': '300 cals'},
#     {'top': 374.32724,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.559417724609375,
#      'text': 'Medium'}],
#    [{'top': 396.88666,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.440582275390625,
#      'text': 'Mussels'},
#     {'top': 396.88666,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.440582275390625,
#      'text': '90 cals'},
#     {'top': 396.88666,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.440582275390625,
#      'text': '90 cals'},
#     {'top': 396.88666,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.440582275390625,
#      'text': 'Low-Med'}],
#    [{'top': 419.32724,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.5594482421875,
#      'text': 'Pheasant roast'},
#     {'top': 419.32724,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.5594482421875,
#      'text': '200 cals'},
#     {'top': 419.32724,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.5594482421875,
#      'text': '200 cals'},
#     {'top': 419.32724,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.5594482421875,
#      'text': 'Medium'}],
#    [{'top': 441.8867,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.44061279296875,
#      'text': 'Pilchards (tinned)'},
#     {'top': 441.8867,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.44061279296875,
#      'text': '140 cals'},
#     {'top': 441.8867,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.44061279296875,
#      'text': '140 cals'},
#     {'top': 441.8867,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.44061279296875,
#      'text': 'Medium'}],
#    [{'top': 464.3273,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.559326171875,
#      'text': 'Prawns'},
#     {'top': 464.3273,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.559326171875,
#      'text': '180 cals'},
#     {'top': 464.3273,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.559326171875,
#      'text': '100 cals'},
#     {'top': 464.3273,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.559326171875,
#      'text': 'Low- Med'}],
#    [{'top': 486.88663,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.440673828125,
#      'text': 'Pork'},
#     {'top': 486.88663,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.440673828125,
#      'text': '320 cals'},
#     {'top': 486.88663,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.440673828125,
#      'text': '290 cals'},
#     {'top': 486.88663,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.440673828125,
#      'text': 'Med-High'}],
#    [{'top': 509.3273,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.559234619140625,
#      'text': 'Pork pie'},
#     {'top': 509.3273,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.559234619140625,
#      'text': '320 cals'},
#     {'top': 509.3273,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.559234619140625,
#      'text': '450 cals'},
#     {'top': 509.3273,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.559234619140625,
#      'text': 'High'}],
#    [{'top': 531.88654,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.440673828125,
#      'text': 'Rabbit'},
#     {'top': 531.88654,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.440673828125,
#      'text': '200 cals'},
#     {'top': 531.88654,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.440673828125,
#      'text': '180 cals'},
#     {'top': 531.88654,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.440673828125,
#      'text': 'Medium'}],
#    [{'top': 554.3272,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.559326171875,
#      'text': 'Salmon fresh'},
#     {'top': 554.3272,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.559326171875,
#      'text': '220 cals'},
#     {'top': 554.3272,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.559326171875,
#      'text': '180 cals'},
#     {'top': 554.3272,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.559326171875,
#      'text': 'Medium'}],
#    [{'top': 576.88654,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.4405517578125,
#      'text': 'Sardines tinned in oil'},
#     {'top': 576.88654,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.4405517578125,
#      'text': '220 cals'},
#     {'top': 576.88654,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.4405517578125,
#      'text': '220 cals'},
#     {'top': 576.88654,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.4405517578125,
#      'text': 'Medium'}],
#    [{'top': 599.3271,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.5596923828125,
#      'text': 'Sardines in tomato sauce'},
#     {'top': 599.3271,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.5596923828125,
#      'text': '180 cals'},
#     {'top': 599.3271,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.5596923828125,
#      'text': '180 cals'},
#     {'top': 599.3271,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.5596923828125,
#      'text': 'Medium'}],
#    [{'top': 621.8868,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.4400634765625,
#      'text': 'Sausage pork fried'},
#     {'top': 621.8868,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.4400634765625,
#      'text': '250 cals'},
#     {'top': 621.8868,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.4400634765625,
#      'text': '320 cals'},
#     {'top': 621.8868,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.4400634765625,
#      'text': 'High'}],
#    [{'top': 644.32684,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.5601806640625,
#      'text': 'Sausage pork grilled'},
#     {'top': 644.32684,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.5601806640625,
#      'text': '220 cals'},
#     {'top': 644.32684,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.5601806640625,
#      'text': '280 cals'},
#     {'top': 644.32684,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.5601806640625,
#      'text': 'Med-High'}],
#    [{'top': 666.887,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.43994140625,
#      'text': 'Sausage roll'},
#     {'top': 666.887,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.43994140625,
#      'text': '290 cals'},
#     {'top': 666.887,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.43994140625,
#      'text': '480 cals'},
#     {'top': 666.887,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.43994140625,
#      'text': 'High'}],
#    [{'top': 689.32697,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 22.56024169921875,
#      'text': 'Scampi fried in oil'},
#     {'top': 689.32697,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 22.56024169921875,
#      'text': '400 cals'},
#     {'top': 689.32697,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 22.56024169921875,
#      'text': '340 cals'},
#     {'top': 689.32697,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 22.56024169921875,
#      'text': 'High'}],
#    [{'top': 711.8872,
#      'left': 66.551025,
#      'width': 153.16781616210938,
#      'height': 20.995361328125,
#      'text': 'Steak & kidney pie'},
#     {'top': 711.8872,
#      'left': 219.71884,
#      'width': 119.87820434570312,
#      'height': 20.995361328125,
#      'text': '400 cals'},
#     {'top': 711.8872,
#      'left': 339.59705,
#      'width': 100.56307983398438,
#      'height': 20.995361328125,
#      'text': '350 cals'},
#     {'top': 711.8872,
#      'left': 440.16013,
#      'width': 105.28457641601562,
#      'height': 20.995361328125,
#      'text': 'High'}]]}]

# %%
df = read_pdf("Food Calories List.pdf", pages='all', multiple_tables=True)
df
# Out:
# [              BREADS & CEREALS               Portion size *  \
#  0          Bagel ( 1 average )               140 cals (45g)
#  1           Biscuit digestives        86 cals (per biscuit)
#  2                   Jaffa cake        48 cals (per biscuit)
#  3    Bread white (thick slice)       96  cals (1 slice 40g)
#  4      Bread wholemeal (thick)       88  cals (1 slice 40g)
#  5                     Chapatis                     250 cals
#  6                   Cornflakes              130  cals (35g)
#  7                 Crackerbread            17 cals per slice
#  8               Cream crackers        35 cals (per cracker)
#  9                     Crumpets        93 cals (per crumpet)
#  10   Flapjacks basic fruit mix                     320 cals
#  11           Macaroni (boiled)              238 cals (250g)
#  12                      Muesli              195  cals (50g)
#  13         Naan bread (normal)  300 cals (small plate size)
#  14            Noodles (boiled)              175 cals (250g)
#  15     Pasta ( normal boiled )              330 cals (300g)
#  16   Pasta (wholemeal boiled )              315 cals (300g)
#  17  Porridge oats (with water)              193 cals (350g)
#  18         Potatoes** (boiled)              210 cals (300g)
#  19          Potatoes** (roast)              420 cals (300g)
#
#     per 100 grams (3.5 oz)  Unnamed: 0 energy content
#  0                310 cals         NaN         Medium
#  1                480 cals         NaN           High
#  2                370 cals         NaN       Med-High
#  3                240 cals         NaN         Medium
#  4                220 cals         NaN        Low-med
#  5                300 cals         NaN         Medium
#  6                370 cals         NaN       Med-High
#  7                325 cals         NaN    Low Calorie
#  8                440 cals         NaN  Low / portion
#  9                198 cals         NaN        Low-Med
#  10               500 cals         NaN           High
#  11                95 cals         NaN    Low calorie
#  12               390 cals         NaN       Med-high
#  13               320 cals         NaN         Medium
#  14                70 cals         NaN    Low calorie
#  15               110 cals         NaN    Low calorie
#  16               105 cals         NaN    Low calorie
#  17                55 cals         NaN    Low calorie
#  18                70 cals         NaN    Low calorie
#  19               140 cals         NaN         Medium  ,
#      Rice (white boiled)    420 cals (300g)  140 cals  Unnamed: 0  \
#  0                   NaN                NaN       NaN         NaN
#  1      Rice (egg-fried)           500 cals  200 cals         NaN
#  2        Rice ( Brown )    405 cals (300g)  135 cals         NaN
#  3            Rice cakes  28 Cals = 1 slice  373 Cals         NaN
#  4    Ryvita Multi grain  37 Cals per slice  331 Cals         NaN
#  5  Ryvita + seed & Oats  180 Cals 4 slices  362 Cals         NaN
#  6    Spaghetti (boiled)    303 cals (300g)  101 cals         NaN
#
#         Low calorie
#  0              NaN
#  1  High in portion
#  2      Low calorie
#  3           Medium
#  4           Medium
#  5           Medium
#  6      Low calorie  ,
#                 Unnamed: 0            Unnamed: 1 Unnamed: 2 per 100 grams  \
#  0                     NaN          Meats & Fish        NaN           NaN
#  1                     NaN                   NaN   (3.5 oz)           NaN
#  2                     NaN                   NaN        NaN           NaN
#  3        Anchovies tinned              300 cals   300 cals        Medium
#  4     Bacon average fried  250 cals (2 rashers)   500 cals          High
#  5   Bacon average grilled              150 cals   380 cals      Med-High
#  6            Beef (roast)              300 cals   280 cals        Medium
#  7     Beef burgers frozen              320 cals   280 cals      Med-High
#  8                 Chicken              220 cals   200 cals        Medium
#  9                 Cockles               50 cals    50 cals           Low
#  10              Cod fresh              150 cals   100 cals   Low calorie
#  11     Cod chip shop food              400 cals   200 cals      Med-High
#  12             Crab fresh              200 cals   110 cals   low calorie
#  13             Duck roast              400 cals   430 cals          High
#
#          Unnamed: 3  Unnamed: 4  Unnamed: 5      Unnamed: 6  Unnamed: 7
#  0   Portion size *         NaN         NaN  energy content         NaN
#  1              NaN         NaN         NaN             NaN         NaN
#  2              NaN         NaN         NaN             NaN         NaN
#  3              NaN         NaN         NaN             NaN         NaN
#  4              NaN         NaN         NaN             NaN         NaN
#  5              NaN         NaN         NaN             NaN         NaN
#  6              NaN         NaN         NaN             NaN         NaN
#  7              NaN         NaN         NaN             NaN         NaN
#  8              NaN         NaN         NaN             NaN         NaN
#  9              NaN         NaN         NaN             NaN         NaN
#  10             NaN         NaN         NaN             NaN         NaN
#  11             NaN         NaN         NaN             NaN         NaN
#  12             NaN         NaN         NaN             NaN         NaN
#  13             NaN         NaN         NaN             NaN         NaN  ,
#                     Fish cake   90 cals per cake  200 cals       Medium
#  0               Fish fingers  50 cals per piece  220 cals       Medium
#  1                     Gammon           320 cals  280 cals     Med-High
#  2              Haddock fresh           200 cals  110 cals  Low calorie
#  3              Halibut fresh           220 cals  125 cals  Low calorie
#  4                        NaN                NaN       NaN          NaN
#  5                        Ham             6 cals  240 cals       Medium
#  6      Herring fresh grilled           300 cals  200 cals       Medium
#  7                     Kidney           200 cals  160 cals       Medium
#  8                     Kipper           200 cals  120 cals  Low calorie
#  9                        NaN                NaN       NaN          NaN
#  10                     Liver           200 cals  150 cals       Medium
#  11                Liver pate           150 cals  300 cals       Medium
#  12              Lamb (roast)           300 cals  300 cals     Med-High
#  13            Lobster boiled           200 cals  100 cals  Low calorie
#  14                       NaN                NaN       NaN          NaN
#  15             Luncheon meat           300 cals  400 cals         High
#  16                  Mackeral           320 cals  300 cals       Medium
#  17                   Mussels            90 cals   90 cals      Low-Med
#  18            Pheasant roast           200 cals  200 cals       Medium
#  19        Pilchards (tinned)           140 cals  140 cals       Medium
#  20                    Prawns           180 cals  100 cals     Low- Med
#  21                      Pork           320 cals  290 cals     Med-High
#  22                  Pork pie           320 cals  450 cals         High
#  23                    Rabbit           200 cals  180 cals       Medium
#  24              Salmon fresh           220 cals  180 cals       Medium
#  25    Sardines tinned in oil           220 cals  220 cals       Medium
#  26  Sardines in tomato sauce           180 cals  180 cals       Medium
#  27        Sausage pork fried           250 cals  320 cals         High
#  28      Sausage pork grilled           220 cals  280 cals     Med-High
#  29              Sausage roll           290 cals  480 cals         High
#  30       Scampi fried in oil           400 cals  340 cals         High
#  31        Steak & kidney pie           400 cals  350 cals         High,
#          Taramasalata  130 cals  490 cals         High
#  0        Trout fresh  200 cals  120 cals  Low calorie
#  1                NaN       NaN       NaN          NaN
#  2  Tuna tinned water  100 cals  100 cals  Low calorie
#  3                NaN       NaN       NaN          NaN
#  4    Tuna tinned oil  180 cals  180 cals       Medium
#  5             Turkey  200 cals  160 cals       Medium
#  6               Veal  300 cals  240 cals       Medium,
#                Unnamed: 0           Unnamed: 1    Unnamed: 2  \
#  0                    NaN  Fruits & Vegetables           NaN
#  1                    NaN                  NaN           oz)
#  2                    NaN                  NaN           NaN
#  3                  Apple          44 calories   44 calories
#  4                 Banana             107 cals   65 calories
#  5      Beans baked beans             170 cals   80 calories
#  6   Beans dried (boiled)             180 cals  130 calories
#  7           Blackberries              25 cals   25 calories
#  8           Blackcurrant              30 cals   30 calories
#  9               Broccoli              27 cals       32 cals
#  10      Cabbage (boiled)          15 calories   20 calories
#  11       Carrot (boiled)          16 calories   25 calories
#  12  Cauliflower (boiled)          20 calories   30 calories
#  13       Celery (boiled)           5 calories   10 calories
#  14                Cherry          35 calories   50 calories
#  15             Courgette               8 cals       20 cals
#  16              Cucumber           3 calories   10 calories
#  17                 Dates         100 calories  235 calories
#  18                Grapes          55 calories   62 calories
#  19            Grapefruit          32 calories   32 calories
#  20                  Kiwi          40 calories   50 calories
#  21         Leek (boiled)          10 calories   20 calories
#
#     per 100 grams (3.5      Unnamed: 3  Unnamed: 4  Unnamed: 5      Unnamed: 6  \
#  0                 NaN  Portion size *         NaN         NaN  energy content
#  1                 NaN             NaN         NaN         NaN             NaN
#  2                 NaN             NaN         NaN         NaN             NaN
#  3         Low calorie             NaN         NaN         NaN             NaN
#  4         Low calorie             NaN         NaN         NaN             NaN
#  5         Low calorie             NaN         NaN         NaN             NaN
#  6         Low calorie             NaN         NaN         NaN             NaN
#  7         Low calorie             NaN         NaN         NaN             NaN
#  8         Low calorie             NaN         NaN         NaN             NaN
#  9            Very low             NaN         NaN         NaN             NaN
#  10        Low calorie             NaN         NaN         NaN             NaN
#  11        Low calorie             NaN         NaN         NaN             NaN
#  12        Low calorie             NaN         NaN         NaN             NaN
#  13        Low calorie             NaN         NaN         NaN             NaN
#  14        Low calorie             NaN         NaN         NaN             NaN
#  15       Very low cal             NaN         NaN         NaN             NaN
#  16        Low calorie             NaN         NaN         NaN             NaN
#  17           Med-High             NaN         NaN         NaN             NaN
#  18        Low calorie             NaN         NaN         NaN             NaN
#  19        Low calorie             NaN         NaN         NaN             NaN
#  20        Low calorie             NaN         NaN         NaN             NaN
#  21        Low calorie             NaN         NaN         NaN             NaN
#
#      Unnamed: 7
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN
#  17         NaN
#  18         NaN
#  19         NaN
#  20         NaN
#  21         NaN  ,
#                Lentils (boiled)      150 calories  100 calories        Medium
#  0                      Lettuce        4 calories   15 calories      Very Low
#  1                        Melon       14 calories   28 calories        Medium
#  2   Mushrooms raw one\raverage            3 cals       15 cals  Very low cal
#  3           Mushrooms (boiled)       12 calories   12 calories   Low calorie
#  4            Mushrooms (fried)      100 calories  145 calories          High
#  5                       Olives       50 calories   80 calories   Low calorie
#  6               Onion (boiled)       14 calories   18 calories   Low calorie
#  7                One red Onion           49 cals       33 cals   Low calorie
#  8                Onions spring            3 cals       25 cals  Very low cal
#  9                Onion (fried)       86 calories  155 calories          High
#  10                      Orange       40 calories   30 calories   Low calorie
#  11                        Peas      210 calories  148 calories        Medium
#  12         Peas dried & boiled      200 calories  120 calories   Low calorie
#  13                       Peach       35 calories   30 calories   Low calorie
#  14                        Pear       45 calories   38 calories   Low calorie
#  15               Pepper yellow            6 cals       16 cals      Very low
#  16                   Pineapple       40 calories   40 calories   Low calorie
#  17                        Plum       30 calories   39 calories   Low calorie
#  18                     Spinach        8 calories    8 calories   Low calorie
#  19    Strawberries (1 average)       10 calories   30 calories   Low calorie
#  20                   Sweetcorn       95 calories  130 calories        Medium
#  21        Sweetcorn on the cob       70 calories   70 calories   Low calorie
#  22                      Tomato       30 calories   20 calories   Low calorie
#  23               Tomato cherry  6 cals ( 3 toms)       17 Cals  Very low cal
#  24                Tomato puree       70 calories   70 calories    Low-Medium
#  25                  Watercress        5 calories   20 calories   Low calorie,
#               Milk & Dairy produce              Portion size *  \
#  0                  Cheese average              110 cals (25g)
#  1   Cheddar types average reduced                         NaN
#  2                             fat                         130
#  3          Cheese spreads average                     90 cals
#  4          Cottage cheese low fat                 40 calories
#  5                  Cottage cheese                     49 cals
#  6                    Cream cheese                    200 cals
#  7                Cream fresh half                    128 cals
#  8              Cream fresh single                    160 cals
#  9              Cream fresh double                    340 cals
#  10            Cream fresh clotted                    480 cals
#  11                        Custard                    210 cals
#  12         Eggs ( 1 average size)                     90 cals
#  13                     Eggs fried                    120 cals
#  14                  Fromage frais                    125 cals
#  15                      Ice cream                    200 cals
#  16                     Milk whole  175 cals (250ml/half pint)
#  17              Milk semi-skimmed  125 cals (250ml/half pint)
#  18                   Milk skimmed   95 cals (250ml/half pint)
#  19                      Milk Soya                     90 cals
#  20                Mousse flavored                    120 cals
#  21           Omelette with cheese                    300 cals
#  22              Trifle with cream                    290 cals
#  23                 Yogurt natural                     90 cals
#  24             Yogurt reduced fat                     70 cals
#
#     per 100 grams (3.5 oz)  Unnamed: 0 energy content
#  0                440 cals         NaN           High
#  1                     NaN         NaN            NaN
#  2            260 calories         NaN         Medium
#  3                     270         NaN         Medium
#  4                 80 cals         NaN      low - med
#  5                 98 cals         NaN    Low calorie
#  6                428 cals         NaN           High
#  7                160 cals         NaN       Med-High
#  8                200 cals         NaN       Med-High
#  9                430 cals         NaN           High
#  10               600 cals         NaN           High
#  11               100 cals         NaN         Medium
#  12               150 cals         NaN         Medium
#  13               180 cals         NaN       Med-High
#  14               125 cals         NaN    Low calorie
#  15               180 cals         NaN         Medium
#  16                70 cals         NaN       Med-High
#  17                50 cals         NaN         Medium
#  18                38 cals         NaN    Low calorie
#  19                36 cals         NaN    Low calorie
#  20               140 cals         NaN         Medium
#  21               266 cals         NaN         Medium
#  22               190 cals         NaN         Medium
#  23                60 cals         NaN    Low calorie
#  24                45 cals         NaN    Low calorie  ,
#                     Fats & Sugars        Portion size * per 100 grams (3.5 oz)  \
#  0                       PURE FAT       9 cals (1 gram)               900 cals
#  1                     Bombay mix              250 cals               500 cals
#  2                         Butter              112 cals               750 cals
#  3                    Chewing gum      8 cals per piece                      -
#  4                      Chocolate              200 cals               500 cals
#  5                  Cod liver oil  135 cals (1 tbspoon)               900 cals
#  6                     Corn snack              125 cals               500 cals
#  7      Crisps (chips US) average              100 cals               500 cals
#  8                          Honey               42 cals               280 cals
#  9                            Jam               38 cals               250 cals
#  10                          Lard              225 cals               890 cals
#  11                Low fat spread               50 cals               400 cals
#  12                     Margarine               50 cals               750 cals
#  13                      Mars bar              240 cals               480 cals
#  14                   Mint sweets     10 cals per piece                      -
#  15  Oils -corn, sunflower, olive  135 cals (1 Tbspoon)               900 cals
#  16               Popcorn average              150 cals               460 cals
#  17       Sugar white table sugar    20 cals (1 tspoon)               400 cals
#  18               Sweets (boiled)              100 cals               300 cals
#  19                         Syrup               15 cals               300 cals
#  20                        Toffee              100 cals               400 cals
#
#      Unnamed: 0 energy content
#  0          NaN           High
#  1          NaN           High
#  2          NaN           High
#  3          NaN    Low calorie
#  4          NaN           High
#  5          NaN           High
#  6          NaN           High
#  7          NaN           High
#  8          NaN         Medium
#  9          NaN         Medium
#  10         NaN           High
#  11         NaN           High
#  12         NaN           High
#  13         NaN       Med-High
#  14         NaN           High
#  15         NaN           High
#  16         NaN           High
#  17         NaN         Medium
#  18         NaN       Med-High
#  19         NaN         Medium
#  20         NaN           High  ,
#                               Fruit Calories per piece Carbs (grams)  \
#  0                Apple (1 average)        44 calories          10.5
#  1                    Apple cooking        35 calories             9
#  2                          Apricot        30 calories           6.7
#  3                          Avocado       150 calories             2
#  4                           Banana       107 calories            26
#  5                Blackberries each          1 calorie           0.2
#  6                Blackcurrant each        1.1 calorie          0.25
#  7          Blueberries  (new) 100g   49 Cals ( 100g )          15 g
#  8                      Cherry each       2.4 calories           0.6
#  9                       Clementine            24 cals             5
#  10                        Currants         5 calories           1.4
#  11                          Damson        28 calories           7.2
#  12             One average date 5g             5 cals           1.2
#  13  Dates with inverted sugar 100g       250 calories            63
#  14                            Figs        10 calories           2.4
#  15                    Gooseberries       2.6 calories          0.65
#  16            Grapes 100g Seedless            50 cals            15
#  17            one average Grape 6g         3 calories           0.9
#  18                Grapefruit whole       100 calories            23
#  19                           Guava        24 calories           4.4
#  20                            Kiwi        34 calories             8
#  21                           Lemon        20 calories           3.4
#  22                         Lychees         3 calories           0.7
#  23                           Mango        40 calories           9.5
#  24           Melon Honeydew (130g)        36 calories             9
#  25         Melon Canteloupe (130g)            25 cals             6
#  26                      Nectarines        42 calories             9
#  27                          Olives       6.8 calories         trace
#
#     Water Content
#  0           85 %
#  1           88 %
#  2           85 %
#  3           60 %
#  4           75 %
#  5           85 %
#  6           77 %
#  7           81 %
#  8           83 %
#  9           66 %
#  10          16 %
#  11          70 %
#  12          14 %
#  13          12 %
#  14          24 %
#  15          80 %
#  16          82 %
#  17          82 %
#  18          65 %
#  19          85 %
#  20          75 %
#  21          85 %
#  22          80 %
#  23          80 %
#  24          90 %
#  25          93 %
#  26          80 %
#  27          63 %  ,
#                        Orange average     35 calories  8.5  73 %
#  0                  Orange large 350g        100 Cals  22g  75 %
#  1       Papaya Diced (small handful)  67 Cals  (20g)  17g     -
#  2                      Passion Fruit     30 calories    3  50 %
#  3                            Paw Paw     28 calories    6  70 %
#  4                              Peach     35 calories    7  80 %
#  5                               Pear     45 calories   12  77 %
#  6                          Pineapple     50 calories   12  85 %
#  7                               Plum     25 calories    6  79 %
#  8                             Prunes      9 calories  2.2  37 %
#  9                            Raisins      5 calories  1.4  13 %
#  10                  Raspberries each    1.1 calories  0.2  87 %
#  11                           Rhubarb      8 calories  0.8  95 %
#  12          Satsuma one average 112g         29 cals  6.5  88 %
#  13                     Satsumas 100g     35 calories  8.5  88 %
#  14          Strawberries (1 average)    2.7 calories  0.6  90 %
#  15                          Sultanas      5 calories  1.4  16 %
#  16                         Tangerine     26 calories    6  60 %
#  17         Tomatoes (1 average size)          9 cals  2.2  93 %
#  18  Tomatoes Cherry (1 average size)      2 calories  0.5  90 %]

# %%
df = read_pdf("Food Calories List.pdf", pages=3)
df
# Out:
# [                   Fish cake   90 cals per cake  200 cals       Medium
#  0               Fish fingers  50 cals per piece  220 cals       Medium
#  1                     Gammon           320 cals  280 cals     Med-High
#  2              Haddock fresh           200 cals  110 cals  Low calorie
#  3              Halibut fresh           220 cals  125 cals  Low calorie
#  4                        NaN                NaN       NaN          NaN
#  5                        Ham             6 cals  240 cals       Medium
#  6      Herring fresh grilled           300 cals  200 cals       Medium
#  7                     Kidney           200 cals  160 cals       Medium
#  8                     Kipper           200 cals  120 cals  Low calorie
#  9                        NaN                NaN       NaN          NaN
#  10                     Liver           200 cals  150 cals       Medium
#  11                Liver pate           150 cals  300 cals       Medium
#  12              Lamb (roast)           300 cals  300 cals     Med-High
#  13            Lobster boiled           200 cals  100 cals  Low calorie
#  14                       NaN                NaN       NaN          NaN
#  15             Luncheon meat           300 cals  400 cals         High
#  16                  Mackeral           320 cals  300 cals       Medium
#  17                   Mussels            90 cals   90 cals      Low-Med
#  18            Pheasant roast           200 cals  200 cals       Medium
#  19        Pilchards (tinned)           140 cals  140 cals       Medium
#  20                    Prawns           180 cals  100 cals     Low- Med
#  21                      Pork           320 cals  290 cals     Med-High
#  22                  Pork pie           320 cals  450 cals         High
#  23                    Rabbit           200 cals  180 cals       Medium
#  24              Salmon fresh           220 cals  180 cals       Medium
#  25    Sardines tinned in oil           220 cals  220 cals       Medium
#  26  Sardines in tomato sauce           180 cals  180 cals       Medium
#  27        Sausage pork fried           250 cals  320 cals         High
#  28      Sausage pork grilled           220 cals  280 cals     Med-High
#  29              Sausage roll           290 cals  480 cals         High
#  30       Scampi fried in oil           400 cals  340 cals         High
#  31        Steak & kidney pie           400 cals  350 cals         High]

# %%
df = read_pdf("Food Calories List.pdf", encoding = 'ISO-8859-1',
         stream=True, area = [269.875, 12.75, 790.5, 961], pages = 4, guess = False,  pandas_options={'header':None})
df
# Out:
# [                       0               1             2               3
#  0    Fruits & Vegetables  Portion size *           oz)  energy content
#  1                  Apple     44 calories   44 calories     Low calorie
#  2                 Banana        107 cals   65 calories     Low calorie
#  3      Beans baked beans        170 cals   80 calories     Low calorie
#  4   Beans dried (boiled)        180 cals  130 calories     Low calorie
#  5           Blackberries         25 cals   25 calories     Low calorie
#  6           Blackcurrant         30 cals   30 calories     Low calorie
#  7               Broccoli         27 cals       32 cals        Very low
#  8       Cabbage (boiled)     15 calories   20 calories     Low calorie
#  9        Carrot (boiled)     16 calories   25 calories     Low calorie
#  10  Cauliflower (boiled)     20 calories   30 calories     Low calorie
#  11       Celery (boiled)      5 calories   10 calories     Low calorie
#  12                Cherry     35 calories   50 calories     Low calorie
#  13             Courgette          8 cals       20 cals    Very low cal
#  14              Cucumber      3 calories   10 calories     Low calorie
#  15                 Dates    100 calories  235 calories        Med-High
#  16                Grapes     55 calories   62 calories     Low calorie
#  17            Grapefruit     32 calories   32 calories     Low calorie
#  18                  Kiwi     40 calories   50 calories     Low calorie
#  19         Leek (boiled)     10 calories   20 calories     Low calorie]

# %%
df = read_pdf("output.pdf", encoding = 'ISO-8859-1',
         stream=True, guess = False)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-9d59d2e17b87> in <module>
#       1 df = read_pdf("output.pdf", encoding = 'ISO-8859-1',
# ----> 2          stream=True, guess = False)
#       3 df
#
# D:\ProgramData\Anaconda3\lib\site-packages\tabula\io.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
#     307
#     308     if not os.path.exists(path):
# --> 309         raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), path)
#     310
#     311     if os.path.getsize(path) == 0:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output.pdf'

# %%
df = read_pdf("./tmp/pdf/output.pdf", encoding = 'ISO-8859-1',
         stream=True, area=[269.875, 12.75, 790.5, 961], guess = False)
df
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# 5          NaN                                              Cloud
# 6          NaN                                         technology
# 7          NaN                                                NaN
# 8          NaN                                                NaN
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 11         NaN                                           Advanced
# 12         NaN                                           robotics
# 13         NaN                                                NaN
# 14         NaN                                                NaN
# 15         NaN                                                NaN
# 16         NaN                                         Autonomous
# 17         NaN                                          and near-
# 18         NaN                                         autonomous
# 19         NaN                                           vehicles
# 20         NaN                                                NaN
# 21         NaN                                                NaN
# 22         NaN                                                NaN
# 23         NaN                                                NaN
# 24         NaN                                                NaN
# 25         NaN                                              Next-
# 26         NaN                                         generation
# 27         NaN                                           genomics
# 28         NaN                                                NaN
# 29         NaN                                                NaN
# 30         NaN                                             Energy
# 31         NaN                                            storage
# 32         NaN                                                NaN
# 33         NaN                                                NaN
# 34         NaN                                                NaN
# 35         NaN                                                NaN
# 36         NaN                                        3D printing
# 37         NaN                                                NaN
# 38         NaN                                                NaN
# 39         NaN                                                NaN
# 40         NaN                                                NaN
# 41         NaN                                           Advanced
# 42         NaN                                          materials
# 43         NaN                                                NaN
# 44         NaN                                                NaN
# 45         NaN                                                NaN
# 46         NaN                                           Advanced
# 47         NaN                                        oil and gas
# 48         NaN                                        exploration
# 49         NaN                                       and recovery
# 50         NaN                                                NaN
# 51         NaN                                          Renewable
# 52         NaN                                             energy
# 53         NaN                                                NaN
# 54         NaN                                                NaN
# 55         NaN                                                NaN
# 56         NaN                                                NaN
# 57         1.0  Not comprehensive; indicative groups, products...
# 58         2.0  For CDC-7600, considered the worldâs fastest...
# 59         3.0  Baxter is a general-purpose basic manufacturin...
#
#    over past 5 years across industries such as manufacturing,  \
# 0                    80â90% health care, and mining
# 1   Price decline in MEMS (microelectromechanical ...
# 2   systems) sensors in past 5 years Global machin...
# 3     connections across sectors like transportation,
# 4                security, health care, and utilities
# 5                                18 months  2 billion
# 6   Time to double server performance per dollar G...
# 7                   3x like Gmail, Yahoo, and Hotmail
# 8   Monthly cost of owning a server vs. renting in...
# 9   the cloud North American institutions hosting ...
# 10         to host critical applications on the cloud
# 11                               75â85% 320 million
# 12  Lower price for Baxter3 than a typical industr...
# 13                                     170% workforce
# 14  Growth in sales of industrial robots, 2009â1...
# 15                             Annual major surgeries
# 16                                        7 1 billion
# 17  Miles driven by top-performing driverless car ...
# 18  DARPA Grand Challenge along a 150-mile route 4...
# 19  1,540 Civilian, military, and general aviation...
# 20  Miles cumulatively driven by cars competing in...
# 21                                    Grand Challenge
# 22                                           300,000+
# 23  Miles driven by Googleâs autonomous cars wit...
# 24                1 accident (which was human-caused)
# 25                              10 months  26 million
# 26  Time to double sequencing speed per dollar Ann...
# 27                   100x disease, or type 2 diabetes
# 28  Increase in acreage of genetically modified cr...
# 29         1996â2012 People employed in agriculture
# 30                                     40%  1 billion
# 31  Price decline for a lithium-ion battery pack i...
# 32            electric vehicle since 2009 1.2 billion
# 33               People without access to electricity
# 34                                                NaN
# 35                                                NaN
# 36                                   90%  320 million
# 37  Lower price for a home 3D printer vs. 4 years ...
# 38                                       4x workforce
# 39  Increase in additive manufacturing revenue in ...
# 40  10 years Annual number of toys manufactured gl...
# 41                    $1,000 vs. $50 7.6 million tons
# 42  Difference in price of 1 gram of nanotubes ove...
# 43                        10 years 45,000 metric tons
# 44        115x Annual global carbon fiber consumption
# 45  Strength-to-weight ratio of carbon nanotubes v...
# 46                                      3x 22 billion
# 47  Increase in efficiency of US gas wells, 2007â...
# 48                               2x produced globally
# 49  Increase in efficiency of US oil wells, 2007â...
# 50             Barrels of crude oil produced globally
# 51                                     85% 21,000 TWh
# 52  Lower price for a solar photovoltaic cell per ...
# 53                               2000 13 billion tons
# 54          19x Annual CO2 emissions from electricity
# 55  Growth in solar photovoltaic and wind generati...
# 56                     capacity since 2000 and planes
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
#
#       industries (manufacturing, health care,
# 0                                 and mining)
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                               $1.7 trillion
# 6                 GDP related to the Internet
# 7                                 $3 trillion
# 8                         Enterprise IT spend
# 9                                         NaN
# 10                                        NaN
# 11                                $6 trillion
# 12            Manufacturing worker employment
# 13      costs, 19% of global employment costs
# 14                            $2â3 trillion
# 15                    Cost of major surgeries
# 16                                $4 trillion
# 17                Automobile industry revenue
# 18                               $155 billion
# 19  Revenue from sales of civilian, military,
# 20              and general aviation aircraft
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                              $6.5 trillion
# 26                   Global health-care costs
# 27                              $1.1 trillion
# 28   Global value of wheat, rice, maize, soy,
# 29                                 and barley
# 30                              $2.5 trillion
# 31         Revenue from global consumption of
# 32                        gasoline and diesel
# 33                               $100 billion
# 34         Estimated value of electricity for
# 35        households currently without access
# 36                               $11 trillion
# 37                   Global manufacturing GDP
# 38                                $85 billion
# 39              Revenue from global toy sales
# 40                                        NaN
# 41                              $1.2 trillion
# 42          Revenue from global semiconductor
# 43                                      sales
# 44                                 $4 billion
# 45     Revenue from global carbon fiber sales
# 46                               $800 billion
# 47       Revenue from global sales of natural
# 48                                        gas
# 49                              $3.4 trillion
# 50     Revenue from global sales of crude oil
# 51                              $3.5 trillion
# 52    Value of global electricity consumption
# 53                                $80 billion
# 54              Value of global carbon market
# 55                               transactions
# 56                                        NaN
# 57                                        NaN
# 58                                        NaN
# 59                                        NaN

# %% [markdown]
# ## With Camelot
#
# #### Installation
#
# https://pypi.org/project/camelot-py/
#
# `pip install camelot-py`
#
# #### Camelot readme
#
# https://github.com/socialcopsdev/camelot

# %%
import camelot
tables = camelot.read_pdf("./tmp/pdf//Food Calories List.pdf")
tables[0].df[1:3]
# Out:
#                      0                      1         2       3
# 1  Bagel ( 1 average )         140 cals (45g)  310 cals  Medium
# 2   Biscuit digestives  86 cals (per biscuit)  480 cals    High

# %%
tables1 = camelot.read_pdf("./tmp/pdf/MGI_Disruptive_technologies_Full_report_May2013.pdf", pages='32', area=[269.875, 120.75, 790.5, 561])
print (tabulate(tables1[0].df))
# Out:
# --  -------------
#  0  Mobile
#     Internet
#  1  Automation
#     of knowledge
#     work
#  2  The Internet
#     of Things
#  3  Cloud
#     technology
#  4  Advanced
#     robotics
#  5  Autonomous
#     and near-
#     autonomous
#     vehicles
#  6  Next-
#     generation
#     genomics
#  7  Energy
#     storage
#  8  3D printing
#  9  Advanced
#     materials
# 10  Advanced oil
#     and gas
#     exploration
#     and recovery
# 11  Renewable
#     energy
# --  -------------

# %%
for i in range(30,35):
    print (i)
    tables = camelot.read_pdf("./tmp/pdf/MGI_Disruptive_technologies_Full_report_May2013.pdf", pages='%d' %  i)
    try:
        print (tabulate(tables[0].df))
        print (tabulate(tables[1].df))
    except IndexError:
        print('NOK')
# Out:
# 30
# NOK
# 31
# NOK
# 32
# --  -------------
#  0  Mobile
#     Internet
#  1  Automation
#     of knowledge
#     work
#  2  The Internet
#     of Things
#  3  Cloud
#     technology
#  4  Advanced
#     robotics
#  5  Autonomous
#     and near-
#     autonomous
#     vehicles
#  6  Next-
#     generation
#     genomics
#  7  Energy
#     storage
#  8  3D printing
#  9  Advanced
#     materials
# 10  Advanced oil
#     and gas
#     exploration
#     and recovery
# 11  Renewable
#     energy
# --  -------------
# NOK
# 33
# NOK
# 34
# NOK

# %% [markdown]
# ## Extract by PyPDF2
#
# #### Installation
#
# https://pypi.org/project/PyPDF2/
#
# `pip install PyPDF2`

# %%
import PyPDF2
pdf_file = open('./tmp/pdf/Food Calories List.pdf', 'rb')
read_pdf = PyPDF2.PdfFileReader(pdf_file)
number_of_pages = read_pdf.getNumPages()
page = read_pdf.getPage(2)
page_content = page.extractText()
print (page_content.encode('utf-8'))
# Out:
# b' Fish cake\n 90 cals per cake\n 200 cals\n Medium\n Fish fingers\n 50 cals per piece\n 220 cals\n Medium\n Gammon\n 320 cals\n 280 cals\n Med\n-High\n Haddock fresh\n 200 cals\n 110 cals\n Low calorie\n Halibut fresh\n 220 cals\n 125 cals\n Low calorie\n Ha\nm 6 cals\n 240 cals\n Medium\n Herring fresh grilled\n 300 cals\n 200 cals\n Medium\n Kidney\n 200 cals\n 160 cals\n Medium\n Kipper\n 200 cals\n 120 cals\n Low calorie\n Liver\n 200 cals\n 150 cals\n Medium\n Liver\n pate\n 150 cals\n 300 cals\n Medium\n Lamb (roast)\n 300 cals\n 300 cals\n Med\n-High\n Lobster boiled\n 200 cals\n 100 cals\n Low calorie\n Luncheon meat\n 300 cals\n 400 cals\n High\n Mackeral\n 320 cals\n 300 cal\ns Medium\n Mussels\n 90 cals\n 90 cals\n Low\n-Med\n Pheasant roast\n 200 cals\n 200 cals\n Medium\n Pilchards (tinned)\n 140 cals\n 140 cals\n Medium\n Prawns\n 180 cals\n 100 cals\n Low\n- Med\n Pork \n 320 cals\n 290 cals\n Med\n-High\n Pork pie\n 320 cals\n 450 cals\n High\n Rabbit\n 200 cals\n 180 cals\n Medium\n Salmon fresh\n 220 cals\n 180 cals\n Medium\n Sardines tinned in oil\n 220 cals\n 220 cals\n Medium\n Sardines in tomato sauce\n 180 cals\n 180 cals\n Medium\n Sausage pork fried\n 250 cals\n 320 cals\n High\n Sausage pork grilled\n 220 cals\n 280 cals\n Med\n-High\n Sausage roll\n 290 cals\n 480 cals\n High\n Scampi fried in oil\n 400 cals\n 340 cals\n High\n Steak & kidney pie\n 400 cals\n 350 cals\n High\n '
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
import numpy

table_list = page_content.split('\n')
l = numpy.array_split(table_list, len(table_list)/4)
for i in range(0,5):
    print(l[i])
# Out:
# [' Fish cake' ' 90 cals per cake' ' 200 cals' ' Medium']
# [' Fish fingers' ' 50 cals per piece' ' 220 cals' ' Medium']
# [' Gammon' ' 320 cals' ' 280 cals' ' Med']
# ['-High' ' Haddock fresh' ' 200 cals' ' 110 cals']
# [' Low calorie' ' Halibut fresh' ' 220 cals' ' 125 cals']
