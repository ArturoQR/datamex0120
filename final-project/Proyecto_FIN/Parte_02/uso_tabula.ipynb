# %%
#pip install tabula
#!pip install tabula-py

# %%
#pip install tabulate
# Out:
# ...
#   Created wheel for tabulate: filename=tabulate-0.8.6-cp37-none-any.whl size=23279 sha256=990320388f873f1afe01a6007b8540a3e83e4afea5f57ff56833b26f5aa03c14
#   Stored in directory: C:\Users\Arturo\AppData\Local\pip\Cache\wheels\9c\9b\f4\eb243fdb89676ec00588e8c54bb54360724c06e7fafe95278e
# Successfully built tabulate
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula as tb
#from tabula import read_pdf
from tabulate import tabulate

# %%
#Archivo Claudia_DeAcero
df = tb.read_pdf("S-P-01235 EPD.pdf", pages=13, output_format="json")
df
# Out:
# [{'extraction_method': 'stream',
#   'top': 95.0,
#   'left': 71.0,
#   'width': 468.0,
#   'height': 235.0,
#   'right': 539.0,
#   'bottom': 330.0,
#   'data': [[{'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 100.76,
#      'left': 251.09,
#      'width': 29.529991149902344,
#      'height': 4.019999980926514,
#      'text': 'A1) Raw'},
#     {'top': 100.76,
#      'left': 323.81,
#      'width': 13.319999694824219,
#      'height': 4.019999980926514,
#      'text': 'A2)'},
#     {'top': 100.76,
#      'left': 388.99,
#      'width': 13.319999694824219,
#      'height': 4.019999980926514,
#      'text': 'A3)'},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 100.76,
#      'left': 497.5,
#      'width': 35.220008850097656,
#      'height': 4.019999980926514,
#      'text': 'A4-A5, B1-'}],
#    [{'top': 105.56,
#      'left': 75.74,
# ...

# %%
df2 = tb.read_pdf("S-P-01235 EPD.pdf", pages=13)
df2
# Out:
# [                   Unnamed: 0    Unnamed: 1    A1) Raw             A2)  \
#  0             Impact category          Unit        NaN             NaN
#  1                         NaN           NaN  materials  Transportation
#  2                         NaN      kg Sb eq   1.36E-04        6.89E-05
#  3           Abiotic depletion           NaN        NaN             NaN
#  4                         NaN             %        57%             29%
#  5   Abiotic depletion (fossil            MJ   7.78E+03        4.11E+02
#  6                         NaN           NaN        NaN             NaN
#  7                      fuels)             %        86%              5%
#  8                         NaN     kg CO2 eq   3.56E+02        2.65E+01
#  9    Global warming (GWP100a)           NaN        NaN             NaN
#  10                        NaN             %        57%              4%
#  11                        NaN           NaN        NaN             NaN
# ...

# %%
import pandas

# %%
df3 = tb.read_pdf("S-P-01235 EPD.pdf", encoding = 'ISO-8859-1',
         stream=True, area = [269.875, 12.75, 790.5, 961], pages=13, guess = False,  pandas_options={'header':None})
df3
# Out:
# [                                                   0                      1  \
#  0                                                NaN                  % 85%
#  1                                                NaN  kg PO4--- eq 1.99E-01
#  2                                     Eutrophication                    NaN
#  3                                                NaN                  % 64%
#  4                                                NaN              m3eq 11.6
#  5                           Water scarcity potential                    NaN
#  6                                                NaN                  % 33%
#  7                                                NaN                    NaN
#  8  Figure. 2 Potential environmental impact contr...                    NaN
#  9                                                NaN                    NaN
#
#            2         3         4
#  0        3%       12%      100%
#  1  3.05E-02  8.07E-02  3.10E-01
# ...

# %%
df4 = tb.read_pdf("S-P-01235 EPD.pdf", pages=14)
df4
# Out:
# [                      Unnamed: 0 Unnamed: 1 Unnamed: 2            1) Raw  \
#  0               Output parameter       Unit      Total               NaN
#  1                            NaN        NaN        NaN  materials supply
#  2                Hazardous waste         kg       0.02              0.01
#  3            Non hazardous waste         kg       56.5                32
#  4             Radioactive waste*         kg       0.01              0.01
#  5           Components for reuse         kg          0                 0
#  6        Materials for recycling         kg       29.4                 0
#  7  Materials for energy recovery         kg          0                 0
#  8           Exported electricity         MJ          0                 0
#  9                  Exported heat         MJ          0                 0
#
#                A2)  A3) Manufacturing
#  0             NaN                NaN
#  1  Transportation                NaN
# ...

# %%
# Archivo española S-P-00696.pdf
df5 = tb.read_pdf("S-P-00696.pdf", pages=11)
df5
# Out:
# [                 Unnamed: 0                                          UPSTREAM  \
#  0   Total Categories Impact  ManufacturingUnit Raw Materials  A1 Transport A2
#  1            Global warming                                  kg CO2 eq 452 76
#  2                 potential                                               NaN
#  3                 GWP (100)                                       (%) 59% 10%
#  4                       NaN                                         kg CFC-11
#  5           Ozone depletion                                   5.4E-05 1.4E-05
#  6                       ODP                                                eq
#  7                       NaN                                       (%) 78% 20%
#  8             Acidification                                 kg SO2 eq 2.9 0.4
#  9                        AC                                       (%) 83% 12%
#  10         -3Eutrophication                         kg PO4 eq 7.2E-01 9.7E-02
# ...

# %%
#S-P-00254 Alfa Acciai Hot-rolled reinforcing steel for concrete in bars and coils.pdf
df5 = tb.read_pdf("S-P-00254 Alfa Acciai Hot-rolled reinforcing steel for concrete in bars and coils.pdf", pages=6)
df5
# Out:
# [   ENVIRONMENTAL IMPACTS        Unnamed: 0 Unnamed: 1    Unnamed: 2  \
#  0                    NaN               NaN   UPSTREAM  CORE PROCESS
#  1              POTENTIAL               NaN        NaN           NaN
#  2                    NaN           UNITS /        NaN           NaN
#  3          ENVIRONMENTAL               NaN        NaN           NaN
#  4                    NaN              D.U.      A1 A2           NaN
#  5                IMPACTS               NaN        NaN           NaN
#  6                    GWP    kg CO  eq 7612     538 42           NaN
#  7                    ODP        g CFC 11eq      <1 <1           NaN
#  8                     AP    kg SO  eq 2.42    1.7 0.2           NaN
#  9                     EP   kg PO 0.343- eq   0.1 <0.1           NaN
#  10                  POCP  kg C H 0.12 4 eq  <0.1 <0.1           NaN
#  11                  ADPE           g Sb eq  <0.1 <0.1           NaN
#  12                  ADPF                MJ  9 914 556           NaN
#
# ...
